# %% [markdown]
# A partir del csv hospitales2.csv, generar un archivo CSV de salida,
# que contenga los siguientes campos en este orden:
# * latitude
# * longitude
# * name
# * label
#
# Con los correspondientes datos extraídos del CSV original, el campo name
# tiene que corresponder con la dirección del hospital, y el campo label con
# el nombre del hospital.

# %% [markdown]
# # importar las bibliotecas que usaremos

# %%
import pandas as pd

# %% [markdown]
# # Subir los datos del CSV e imprimirlos en pantalla

# %%
data = pd.read_csv("hospitales2.csv")

# %%
data.head()
# Out:
#                                            WKT   ID  \
# 0  POINT (-58.3775508488443 -34.6288473603881)  1.0
# 1  POINT (-58.4120700769456 -34.5941919726393)  2.0
# 2  POINT (-58.4027276547828 -34.5845283357505)  4.0
# 3  POINT (-58.3851559118889 -34.6394041316484)  6.0
# 4  POINT (-58.3913114406535 -34.6341535760002)  7.0
#
#                                               NOMBRE  \
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                        NOM_MAP    OBJETO                    CALLE  ALTURA  \
# 0            HOSP. DE ELIZALDE  HOSPITAL  MANUEL A. MONTES DE OCA      40
# 1              HOSP. GUTIERREZ  HOSPITAL                    GALLO    1330
# 2  HOSP. ODONTOLOGICO CARRILLO  HOSPITAL    SANCHEZ DE BUSTAMANTE    2529
# ...

# %% [markdown]
# # con tail (cola) miramos la ultima sección del data frame

# %%
data.tail()
# Out:
#                                             WKT    ID  \
# 31  POINT (-58.4710976282168 -34.5873917690227)  34.0
# 32   POINT (-58.4541167814714 -34.643894071866)  35.0
# 33  POINT (-58.4566428491103 -34.6718480140772)  36.0
# 34  POINT (-58.3918791813882 -34.6299453614404)   3.0
# 35  POINT (-58.3814293381891 -34.6419888014928)   5.0
#
#                                                NOMBRE  \
# 31            HOSPITAL GENERAL DE AGUDOS DR. E. TORNU
# 32               HOSPITAL GENERAL DE AGUDOS P. PIÑERO
# 33                          HOSPITAL CECILIA GRIERSON
# 34                 HOSP. DE PEDIATRIA DR. J. GARRAHAN
# 35  TALLERES PROTEGIDOS DE REHABILITACION PSIQUIAT...
#
#                             NOM_MAP    OBJETO  \
# 31                      HOSP. TORNU  HOSPITAL
# 32                     HOSP. PIÑERO  HOSPITAL
# 33                   HOSP. GRIERSON  HOSPITAL
# 34                   HOSP. GARRAHAN  HOSPITAL
# 35  TALLERES DE REHAB. PSIQUIATRICA  HOSPITAL
#
# ...

# %% [markdown]
# # separamos las columnas que necesitamos

# %%
nueva_data = data[["WKT", "NOMBRE", "DOM_NORMA"]]

# %%
nueva_data.head()
# Out:
#                                            WKT  \
# 0  POINT (-58.3775508488443 -34.6288473603881)
# 1  POINT (-58.4120700769456 -34.5941919726393)
# 2  POINT (-58.4027276547828 -34.5845283357505)
# 3  POINT (-58.3851559118889 -34.6394041316484)
# 4  POINT (-58.3913114406535 -34.6341535760002)
#
#                                               NOMBRE  \
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                       DOM_NORMA
# 0  MONTES DE OCA, MANUEL AV. 40
# 1                    GALLO 1330
# 2    SANCHEZ DE BUSTAMANTE 2529
# 3                 BRANDSEN 2570
# 4              CASEROS AV. 2061

# %% [markdown]
# # eliminamos con la palabra clave **del** el anterior dataframe

# %%
del data

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
prueba = [1, 2, 3]

# %%
del prueba

# %%
prueba
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 prueba
#
# NameError: name 'prueba' is not defined

# %% [markdown]
# # distintas formas de escoger una serie del dataframe

# %%
nueva_data.WKT

# %%
nueva_data["WKT"]
# Out:
# 0     POINT (-58.3775508488443 -34.6288473603881)
# 1     POINT (-58.4120700769456 -34.5941919726393)
# 2     POINT (-58.4027276547828 -34.5845283357505)
# 3     POINT (-58.3851559118889 -34.6394041316484)
# 4     POINT (-58.3913114406535 -34.6341535760002)
# 5     POINT (-58.4349433479819 -34.6084721257413)
# 6     POINT (-58.3758433488021 -34.6302112044495)
# 7     POINT (-58.3823284509488 -34.6357022351559)
# 8     POINT (-58.3821283746958 -34.6364350546569)
# 9     POINT (-58.3601201271455 -34.6388917320834)
# 10    POINT (-58.4409882382439 -34.5538963316473)
# 11     POINT (-58.4027506275377 -34.634856308415)
# 12    POINT (-58.4601855775528 -34.6054342750207)
# 13    POINT (-58.4276597542837 -34.6146348348429)
# 14    POINT (-58.4332484381295 -34.6070507603866)
# 15    POINT (-58.4323966950244 -34.6255031952483)
# 16    POINT (-58.3940641604746 -34.6227125075124)
# 17    POINT (-58.5021449222222 -34.6179817540591)
# 18    POINT (-58.3937269413225 -34.6375293258416)
# ...

# %% [markdown]
# # Primero aislamos parte del dataframe para trabajarlo con mas comodidad y hacer los cambios pertinentes para poder sacar las coordenadas

# %%
nueva_variable=nueva_data.WKT[0]

# %%
nueva_variable.replace("POINT ", "")
# Out:
# '(-58.3775508488443 -34.6288473603881)'

# %%
nueva_variable1 = nueva_variable.replace("POINT ", "")

# %%
nueva_variable1.replace("(", "")
# Out:
# '-58.3775508488443 -34.6288473603881)'

# %%
nueva_variable2 = nueva_variable1.replace("(", "")

# %%
nueva_variable2.replace(")", "")
# Out:
# '-58.3775508488443 -34.6288473603881'

# %%
limpio = nueva_variable2.replace(")", "")

# %%
limpio.split(" ")
# Out:
# ['-58.3775508488443', '-34.6288473603881']

# %% [markdown]
# # Luego aplicamos los cambios a la serie

# %%
nueva_data.WKT
# Out:
# 0     POINT (-58.3775508488443 -34.6288473603881)
# 1     POINT (-58.4120700769456 -34.5941919726393)
# 2     POINT (-58.4027276547828 -34.5845283357505)
# 3     POINT (-58.3851559118889 -34.6394041316484)
# 4     POINT (-58.3913114406535 -34.6341535760002)
# 5     POINT (-58.4349433479819 -34.6084721257413)
# 6     POINT (-58.3758433488021 -34.6302112044495)
# 7     POINT (-58.3823284509488 -34.6357022351559)
# 8     POINT (-58.3821283746958 -34.6364350546569)
# 9     POINT (-58.3601201271455 -34.6388917320834)
# 10    POINT (-58.4409882382439 -34.5538963316473)
# 11     POINT (-58.4027506275377 -34.634856308415)
# 12    POINT (-58.4601855775528 -34.6054342750207)
# 13    POINT (-58.4276597542837 -34.6146348348429)
# 14    POINT (-58.4332484381295 -34.6070507603866)
# 15    POINT (-58.4323966950244 -34.6255031952483)
# 16    POINT (-58.3940641604746 -34.6227125075124)
# 17    POINT (-58.5021449222222 -34.6179817540591)
# 18    POINT (-58.3937269413225 -34.6375293258416)
# ...

# %%
nueva_data.WKT.str.replace("POINT ", "")
# Out:
# 0     (-58.3775508488443 -34.6288473603881)
# 1     (-58.4120700769456 -34.5941919726393)
# 2     (-58.4027276547828 -34.5845283357505)
# 3     (-58.3851559118889 -34.6394041316484)
# 4     (-58.3913114406535 -34.6341535760002)
# 5     (-58.4349433479819 -34.6084721257413)
# 6     (-58.3758433488021 -34.6302112044495)
# 7     (-58.3823284509488 -34.6357022351559)
# 8     (-58.3821283746958 -34.6364350546569)
# 9     (-58.3601201271455 -34.6388917320834)
# 10    (-58.4409882382439 -34.5538963316473)
# 11     (-58.4027506275377 -34.634856308415)
# 12    (-58.4601855775528 -34.6054342750207)
# 13    (-58.4276597542837 -34.6146348348429)
# 14    (-58.4332484381295 -34.6070507603866)
# 15    (-58.4323966950244 -34.6255031952483)
# 16    (-58.3940641604746 -34.6227125075124)
# 17    (-58.5021449222222 -34.6179817540591)
# 18    (-58.3937269413225 -34.6375293258416)
# 19    (-58.4752588459761 -34.5972098729151)
# 20    (-58.4005134574423 -34.5847659581214)
# ...

# %%
nueva_data["WKT"] = nueva_data.WKT.str.replace("POINT ", "")
# Out:
# /tmp/ipykernel_9247/1032628392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nueva_data["WKT"] = nueva_data.WKT.str.replace("POINT ", "")

# %%
nueva_data.head()
# Out:
#                                      WKT  \
# 0  (-58.3775508488443 -34.6288473603881)
# 1  (-58.4120700769456 -34.5941919726393)
# 2  (-58.4027276547828 -34.5845283357505)
# 3  (-58.3851559118889 -34.6394041316484)
# 4  (-58.3913114406535 -34.6341535760002)
#
#                                               NOMBRE  \
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                       DOM_NORMA
# 0  MONTES DE OCA, MANUEL AV. 40
# 1                    GALLO 1330
# 2    SANCHEZ DE BUSTAMANTE 2529
# 3                 BRANDSEN 2570
# 4              CASEROS AV. 2061

# %%
nueva_data.WKT.str.replace("(", "")
# Out:
# /tmp/ipykernel_9247/885178067.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nueva_data.WKT.str.replace("(", "")
# 0     -58.3775508488443 -34.6288473603881)
# 1     -58.4120700769456 -34.5941919726393)
# 2     -58.4027276547828 -34.5845283357505)
# 3     -58.3851559118889 -34.6394041316484)
# 4     -58.3913114406535 -34.6341535760002)
# 5     -58.4349433479819 -34.6084721257413)
# 6     -58.3758433488021 -34.6302112044495)
# 7     -58.3823284509488 -34.6357022351559)
# 8     -58.3821283746958 -34.6364350546569)
# 9     -58.3601201271455 -34.6388917320834)
# 10    -58.4409882382439 -34.5538963316473)
# 11     -58.4027506275377 -34.634856308415)
# 12    -58.4601855775528 -34.6054342750207)
# 13    -58.4276597542837 -34.6146348348429)
# 14    -58.4332484381295 -34.6070507603866)
# 15    -58.4323966950244 -34.6255031952483)
# ...

# %%
nueva_data["WKT"] = nueva_data.WKT.str.replace("(", "")
# Out:
# /tmp/ipykernel_9247/1360105125.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nueva_data["WKT"] = nueva_data.WKT.str.replace("(", "")
# /tmp/ipykernel_9247/1360105125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nueva_data["WKT"] = nueva_data.WKT.str.replace("(", "")

# %%
nueva_data.WKT
# Out:
# 0     -58.3775508488443 -34.6288473603881)
# 1     -58.4120700769456 -34.5941919726393)
# 2     -58.4027276547828 -34.5845283357505)
# 3     -58.3851559118889 -34.6394041316484)
# 4     -58.3913114406535 -34.6341535760002)
# 5     -58.4349433479819 -34.6084721257413)
# 6     -58.3758433488021 -34.6302112044495)
# 7     -58.3823284509488 -34.6357022351559)
# 8     -58.3821283746958 -34.6364350546569)
# 9     -58.3601201271455 -34.6388917320834)
# 10    -58.4409882382439 -34.5538963316473)
# 11     -58.4027506275377 -34.634856308415)
# 12    -58.4601855775528 -34.6054342750207)
# 13    -58.4276597542837 -34.6146348348429)
# 14    -58.4332484381295 -34.6070507603866)
# 15    -58.4323966950244 -34.6255031952483)
# 16    -58.3940641604746 -34.6227125075124)
# 17    -58.5021449222222 -34.6179817540591)
# 18    -58.3937269413225 -34.6375293258416)
# 19    -58.4752588459761 -34.5972098729151)
# 20    -58.4005134574423 -34.5847659581214)
# 21     -58.365985088719 -34.6283448581677)
# ...

# %%
nueva_data.WKT.str.replace(")", "")
# Out:
# /tmp/ipykernel_9247/459683528.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nueva_data.WKT.str.replace(")", "")
# 0     -58.3775508488443 -34.6288473603881
# 1     -58.4120700769456 -34.5941919726393
# 2     -58.4027276547828 -34.5845283357505
# 3     -58.3851559118889 -34.6394041316484
# 4     -58.3913114406535 -34.6341535760002
# 5     -58.4349433479819 -34.6084721257413
# 6     -58.3758433488021 -34.6302112044495
# 7     -58.3823284509488 -34.6357022351559
# 8     -58.3821283746958 -34.6364350546569
# 9     -58.3601201271455 -34.6388917320834
# 10    -58.4409882382439 -34.5538963316473
# 11     -58.4027506275377 -34.634856308415
# 12    -58.4601855775528 -34.6054342750207
# 13    -58.4276597542837 -34.6146348348429
# 14    -58.4332484381295 -34.6070507603866
# 15    -58.4323966950244 -34.6255031952483
# ...

# %%
nueva_data["WKT"] = nueva_data.WKT.str.replace(")", "")
# Out:
# /tmp/ipykernel_9247/1553979356.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nueva_data["WKT"] = nueva_data.WKT.str.replace(")", "")
# /tmp/ipykernel_9247/1553979356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nueva_data["WKT"] = nueva_data.WKT.str.replace(")", "")

# %%
nueva_data.head()
# Out:
#                                    WKT  \
# 0  -58.3775508488443 -34.6288473603881
# 1  -58.4120700769456 -34.5941919726393
# 2  -58.4027276547828 -34.5845283357505
# 3  -58.3851559118889 -34.6394041316484
# 4  -58.3913114406535 -34.6341535760002
#
#                                               NOMBRE  \
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                       DOM_NORMA
# 0  MONTES DE OCA, MANUEL AV. 40
# 1                    GALLO 1330
# 2    SANCHEZ DE BUSTAMANTE 2529
# 3                 BRANDSEN 2570
# 4              CASEROS AV. 2061

# %%
nueva_data.WKT.str.split(" ", expand = True)
# Out:
#                     0                  1
# 0   -58.3775508488443  -34.6288473603881
# 1   -58.4120700769456  -34.5941919726393
# 2   -58.4027276547828  -34.5845283357505
# 3   -58.3851559118889  -34.6394041316484
# 4   -58.3913114406535  -34.6341535760002
# 5   -58.4349433479819  -34.6084721257413
# 6   -58.3758433488021  -34.6302112044495
# 7   -58.3823284509488  -34.6357022351559
# 8   -58.3821283746958  -34.6364350546569
# 9   -58.3601201271455  -34.6388917320834
# 10  -58.4409882382439  -34.5538963316473
# 11  -58.4027506275377   -34.634856308415
# 12  -58.4601855775528  -34.6054342750207
# 13  -58.4276597542837  -34.6146348348429
# 14  -58.4332484381295  -34.6070507603866
# 15  -58.4323966950244  -34.6255031952483
# 16  -58.3940641604746  -34.6227125075124
# 17  -58.5021449222222  -34.6179817540591
# 18  -58.3937269413225  -34.6375293258416
# 19  -58.4752588459761  -34.5972098729151
# 20  -58.4005134574423  -34.5847659581214
# 21   -58.365985088719  -34.6283448581677
# ...

# %% [markdown]
# # finalmente Creamos dos columnas y aplicamos los cambios para generar las coordenadas separadas

# %%
nueva_data[["Latitud", "longitud"]] = nueva_data.WKT.str.split(" ", expand = True)
# Out:
# /tmp/ipykernel_9247/3303978478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nueva_data[["Latitud", "longitud"]] = nueva_data.WKT.str.split(" ", expand = True)
# /tmp/ipykernel_9247/3303978478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nueva_data[["Latitud", "longitud"]] = nueva_data.WKT.str.split(" ", expand = True)

# %%
nueva_data.head()
# Out:
#                                    WKT  \
# 0  -58.3775508488443 -34.6288473603881
# 1  -58.4120700769456 -34.5941919726393
# 2  -58.4027276547828 -34.5845283357505
# 3  -58.3851559118889 -34.6394041316484
# 4  -58.3913114406535 -34.6341535760002
#
#                                               NOMBRE  \
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                       DOM_NORMA            Latitud           longitud
# 0  MONTES DE OCA, MANUEL AV. 40  -58.3775508488443  -34.6288473603881
# 1                    GALLO 1330  -58.4120700769456  -34.5941919726393
# 2    SANCHEZ DE BUSTAMANTE 2529  -58.4027276547828  -34.5845283357505
# 3                 BRANDSEN 2570  -58.3851559118889  -34.6394041316484
# ...

# %%
nueva_data.drop("WKT", axis = 1)
# Out:
#                                                NOMBRE  \
# 0         HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1         HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2   HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3             HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4            HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
# 5                    INSTITUTO DE ZOONOSIS L. PASTEUR
# 6   HOSPITAL DE REHABILITACION RESPIRATORIA MARIA ...
# 7            HOSPITAL INFANTO JUVENIL C. TOBAR GARCIA
# 8                HOSPITAL DE SALUD MENTAL J. T. BORDA
# 9   HOSPITAL DE ODONTOLOGIA INFANTIL DON BENITO QU...
# 10  INSTITUTO DE REHABILITACION PSICOFISICA (I.R.E...
# 11                 HOSPITAL MATERNO INFANTIL R. SARDA
# 12          HOSPITAL OFTALMOLOGICO DR. PEDRO LAGLEYZE
# 13               HOSPITAL DE ODONTOLOGIA  JOSE DUEÑAS
# 14        HOSPITAL MUNICIPAL DE ONCOLOGIA MARIE CURIE
# 15      HOSPITAL DE QUEMADOS DR. ARTURO UMBERTO ILLIA
# ...

# %%
nueva_data.head()
# Out:
#                                    WKT  \
# 0  -58.3775508488443 -34.6288473603881
# 1  -58.4120700769456 -34.5941919726393
# 2  -58.4027276547828 -34.5845283357505
# 3  -58.3851559118889 -34.6394041316484
# 4  -58.3913114406535 -34.6341535760002
#
#                                               NOMBRE  \
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                       DOM_NORMA            Latitud           longitud
# 0  MONTES DE OCA, MANUEL AV. 40  -58.3775508488443  -34.6288473603881
# 1                    GALLO 1330  -58.4120700769456  -34.5941919726393
# 2    SANCHEZ DE BUSTAMANTE 2529  -58.4027276547828  -34.5845283357505
# 3                 BRANDSEN 2570  -58.3851559118889  -34.6394041316484
# ...

# %%
nueva_data = nueva_data.drop("WKT", axis = 1)

# %%
nueva_data.drop("WKT", axis = 1, inplace = True)
# Out:
# /tmp/ipykernel_9247/1023228624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nueva_data.drop("WKT", axis = 1, inplace = True)

# %%
nueva_data.head()
# Out:
#                                               NOMBRE  \
# 0        HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1        HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2  HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3            HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4           HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
#
#                       DOM_NORMA            Latitud           longitud
# 0  MONTES DE OCA, MANUEL AV. 40  -58.3775508488443  -34.6288473603881
# 1                    GALLO 1330  -58.4120700769456  -34.5941919726393
# 2    SANCHEZ DE BUSTAMANTE 2529  -58.4027276547828  -34.5845283357505
# 3                 BRANDSEN 2570  -58.3851559118889  -34.6394041316484
# 4              CASEROS AV. 2061  -58.3913114406535  -34.6341535760002

# %% [markdown]
# # Cambiamos nombre de columnas ingresando un diccionario y listo!

# %%
nueva_data.rename(columns = {"NOMBRE":"Label", "DOM_NORMA":"Name", "Latitud":"latitude", "longitud":"longitude"})
# Out:
#                                                 Label  \
# 0         HOSPITAL GENERAL DE NIÑOS PEDRO DE ELIZALDE
# 1         HOSPITAL GENERAL DE NIÑOS RICARDO GUTIERREZ
# 2   HOSPITAL DE ODONTOLOGIA DR. RAMON CARRILLO (EX...
# 3             HOSPITAL DE SALUD MENTAL BRAULIO MOYANO
# 4            HOSPITAL DE GASTROENTEROLOGIA B. UDAONDO
# 5                    INSTITUTO DE ZOONOSIS L. PASTEUR
# 6   HOSPITAL DE REHABILITACION RESPIRATORIA MARIA ...
# 7            HOSPITAL INFANTO JUVENIL C. TOBAR GARCIA
# 8                HOSPITAL DE SALUD MENTAL J. T. BORDA
# 9   HOSPITAL DE ODONTOLOGIA INFANTIL DON BENITO QU...
# 10  INSTITUTO DE REHABILITACION PSICOFISICA (I.R.E...
# 11                 HOSPITAL MATERNO INFANTIL R. SARDA
# 12          HOSPITAL OFTALMOLOGICO DR. PEDRO LAGLEYZE
# 13               HOSPITAL DE ODONTOLOGIA  JOSE DUEÑAS
# 14        HOSPITAL MUNICIPAL DE ONCOLOGIA MARIE CURIE
# 15      HOSPITAL DE QUEMADOS DR. ARTURO UMBERTO ILLIA
# ...

# %%
nueva_data.shape
# Out:
# (36, 4)

# %%
nueva_data.ndim
# Out:
# 2
